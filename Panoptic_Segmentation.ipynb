# %%
# %cd /content
# Out:
# /content

# %%
# %%writefile panoptic_segmentation_func.py

from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
from detectron2 import model_zoo

import cv2
import torch
import numpy as np


_predictor = None
_metadata = None


def load_panoptic_model():

    global _predictor, _metadata

    if _predictor is None:

        cfg = get_cfg()

        cfg.merge_from_file(
            model_zoo.get_config_file(
                "COCO-PanopticSegmentation/panoptic_fpn_R_101_3x.yaml"
            )
        )

        cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(
            "COCO-PanopticSegmentation/panoptic_fpn_R_101_3x.yaml"
        )

        cfg.MODEL.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

        _predictor = DefaultPredictor(cfg)

        _metadata = MetadataCatalog.get(cfg.DATASETS.TRAIN[0])

    return _predictor, _metadata


def run_panoptic_segmentation(image):

    predictor, metadata = load_panoptic_model()

    outputs = predictor(image)

    panoptic_seg, segments_info = outputs["panoptic_seg"]

    return panoptic_seg.to("cpu"), segments_info, metadata


def visualize_panoptic(image, panoptic_seg, segments_info, metadata):

    visualizer = Visualizer(
        image[:, :, ::-1],
        metadata,
        scale=1.0
    )

    out = visualizer.draw_panoptic_seg(
        panoptic_seg,
        segments_info
    )

    result = out.get_image()[:, :, ::-1]

    return result
# Out:
# Overwriting panoptic_segmentation_func.py

# %%
# !ls /content
# Out:
# drone-path  panoptic_segmentation_func.py  sample_data

# %%
# !find /content -name "*.ipynb"
# Out:
# /content/drone-path/yolo_clustering.ipynb

# %%
# !rm -rf /content/drone-path

# %%
# !git clone https://github.com/Daanish-Jain/drone-path.git
# Out:
# Cloning into 'drone-path'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 34 (delta 13), reused 5 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 1.08 MiB | 6.68 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drone-path  panoptic_segmentation_func.py  sample_data

# %%
# !mv Panoptic_Segmentation.ipynb drone-path/
# Out:
# mv: cannot stat 'Panoptic_Segmentation.ipynb': No such file or directory

# %%
# !mv /content/panoptic_segmentation_func.py /content/drone-path/

# %%
# !ls /content/drone-path
# Out:
# panoptic_segmentation_func.py  yolo_clustering_func.py
# README.md		       yolo_clustering.ipynb

# %%
# !git config --global user.email "23ucc534@lnmiit.ac.in"
# !git config --global user.name "Daanish-Jain"

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drone-path
# Out:
# /content/drone-path

# %%
# !ls -a
# Out:
# .     panoptic_segmentation_func.py  yolo_clustering.ipynb
# ..    README.md
# .git  yolo_clustering_func.py

# %%
# !git add panoptic_segmentation_func.py
# !git push https://Daanish-Jain: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@github.com/Daanish-Jain/drone-path.git
# Out:
# Everything up-to-date

# %%
# !git remote set-url origin https://github.com/Daanish-Jain/drone-path.git
